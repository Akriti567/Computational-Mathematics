# %% [markdown]
# Name:Akriti Kumari Dev

# %% [markdown]
# University Id:2329584

# %% [markdown]
# This file contains the assigned tasks' code and an explanation.

# %% [markdown]
# Question 1:

# %% [markdown]
# The revised ‘Harris-Benedict’ method for calculating ‘Basal Metabolic Rate’ (BMR) is as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Based on an individual's level of weekly exercise, the recommended daily kilocalorie intake to maintain current weight can be calculated via;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using this information, create a Py program that will prompt for an individual's details, and their level of weekly exercise, then calculate the corresponding BMR and daily required KC intake and return this information to the user.

# %%
#Akriti Kumari Dev
#University Id=2329584

#Prompt the user to input their gender and convert it to uppercase

gender=input("Enter your gender in M or F: ").upper()

#If the user inputs 'M',calculate their BMR and daily kilocalories intake based on their inputs
if gender=='M':
  age=int(input("Enter your age in years: "))
  weight=int(input("Enter your weight in KG: "))
  height=int(input("Enter your height in cm: "))
  BMR_m = 88.362 + (13.397 * weight)+(4.799 * height)-(5.677*age)


#Print the user's BMR
  print("Your BMR is: ", BMR_m)

#Prompt the user to input their exercise level
  exercise_level=int(input("Enter your exercise level in scale of 0-4: "))

#If the users inputs an exercise level greater than 4,print an error message
  if exercise_level>4:
    print("Please enter your exercise level in scale of 0-4")

#Otherwise, calculate the user's daily kilocalories intake based on thier exercise level
  else:
    if exercise_level==0:
      Daily_kc_intake=BMR_m*1.2
    elif exercise_level==1:
      Daily_kc_intake=BMR_m*1.375
    elif exercise_level==2:
      Daily_kc_intake=BMR_m*1.55
    elif exercise_level==3:
      Daily_kc_intake=BMR_m*1.725
    elif exercise_level==4:
      Daily_kc_intake=BMR_m*1.9
  
#Print the user's daily kilocalories intake
    print("Your daily kilocalories intake required is: ", Daily_kc_intake)

#If the user inputs 'F', calculate their BMR and daily kilocalories intake based on their inputs
elif gender=='F':
  age=int(input("Enter your age in years: "))
  weight=int(input("Enter your weight in KG: "))
  height=float(input("Enter your height in cm: "))
  BMR_f = 447.593 + (9.247 * weight)+(3.098* height)-(4.330*age)

#Print the user's BMR
  print("Your BMR is: ", BMR_f)

#Prompt the user to input their exercise level
  exercise_level=int(input("Enter your exercise level in scale of 0-4: "))

#If the user inputs an exercise level greater than 4,print an error message
  if exercise_level>4:
    print("Please enter your exercise level in scale of 0-4")

#Otherwise, calculate the user's daily kilocalories intake based on their exercise level
  else:
    if exercise_level==0:
      Daily_kc_intake=BMR_f*1.2
    elif exercise_level==1:
      Daily_kc_intake=BMR_f*1.375
    elif exercise_level==2:
      Daily_kc_intake=BMR_f*1.55
    elif exercise_level==3:
      Daily_kc_intake=BMR_f*1.725
    elif exercise_level==4:
      Daily_kc_intake=BMR_f*1.9
  
#Prints dailycalories intake
    print("Your daily kilocalories intake required is: ", Daily_kc_intake)
else:
  print("Gender not valid!")
# Out:
# Enter your gender in M or F: F
# Enter your age in years: 17
# Enter your weight in KG: 55
# Enter your height in cm: 162.56
# Your BMR is:  1386.1788800000002
# Enter your exercise level in scale of 0-4: 1
# Your daily kilocalories intake required is:  1905.9959600000002

# %% [markdown]
# Question 2:

# %% [markdown]
# Create a program that utilises a recursive function to calculate the sum of
# integer values between two given integers inclusive, i.e. 5, and 7 as inputs
# should return 18 (5+6+7). The program should ask the user for the low and high
# numbers to act as the initial and last values in this calculation, then find
# and return the sum. Your program will need to provide feedback if this is not
# possible due to; the input values not being integers, or the ‘low’ value being
# higher than the ‘high’ value.

# %%
#Akriti Kumari Dev
#University Id=2329584

#Define a recursive function to calculate the sum of integers between two given numbers.
def calculate_sum(lower,higher):
  if lower>higher:
     return 0
  else:
     return lower+calculate_sum(lower+1,higher)

#Loop until valid integer inputs are entered for lower and higher numbers
while True:
  lower=input("Enter the lower number")
  higher=input("Enter the higher number")

  try:
    lower=int(lower)
    higher=int(higher)
#check if lower number is high than higher number and print error message
    if lower>higher:
      print("Error:The lower number cannot be high than the higher number.")
      
#Exit loop if valid integer inputs are entered
    else:
      break

#Print error message if invalids inputs are entered
  except ValueError:
    print("Error:The lower and higher number must be integers.")

#Call calculate_sum function and print the result
sum=calculate_sum(lower,higher)
print(f"The sum of integers between{lower} and {higher}is {sum}.")
# Out:
# Enter the lower number2
# Enter the higher number4
# The sum of integers between2 and 4is 9.

# %% [markdown]
# Demonstrate this program works with:

# %% [markdown]
# 1.	The calculation of the sum of values between the first number of your student number and the last two digits of your student number when read as one number. (i.e. with a student number of 543820, the values will be ‘5’ and ‘20’.)

# %% [markdown]
# 2.	The calculation of a low value of “-12” and a high value of your height in feet (rounding up).

# %% [markdown]
# 3.	Suitable feedback for invalid input.

# %% [markdown]
# The code is run once more with the initial number of my student ID and the last two digits of my student ID, which are 2 and 43, to show how it works.(2329584). The lower and upper values are once again entered as "-12" and height in feet (in my example, 5), respectively.

# %%
#Akriti Kumari Dev
#University Id=2329584

#Define a recursive function to calculate the sum of integers between two given numbers.
def calculate_sum(lower,higher):
  if lower>higher:
     return 0
  else:
     return lower+calculate_sum(lower+1,higher)

#Loop until valid integer inputs are entered for lower and higher numbers
while True:
  lower=input("Enter the lower number")
  higher=input("Enter the higher number")

  try:
    lower=int(lower)
    higher=int(higher)
#check if lower number is high than higher number and print error message
    if lower>higher:
      print("Error:The lower number cannot be high than the higher number.")
      
#Exit loop if valid integer inputs are entered
    else:
      break

#Print error message if invalids inputs are entered
  except ValueError:
    print("Error:The lower and higher number must be integers.")

#Call calculate_sum function and print the result
sum=calculate_sum(lower,higher)
print(f"The sum of integers between{lower} and {higher}is {sum}.")
# Out:
# Enter the lower number6
# Enter the higher number8
# The sum of integers between6 and 8is 21.

# %%
#Akriti Kumari Dev
#University Id=2329584

#Define a recursive function to calculate the sum of integers between two given numbers.
def calculate_sum(lower,higher):
  if lower>higher:
     return 0
  else:
     return lower+calculate_sum(lower+1,higher)

#Loop until valid integer inputs are entered for lower and higher numbers
while True:
  lower=input("Enter the lower number")
  higher=input("Enter the higher number")

  try:
    lower=int(lower)
    higher=int(higher)
#check if lower number is high than higher number and print error message
    if lower>higher:
      print("Error:The lower number cannot be high than the higher number.")
      
#Exit loop if valid integer inputs are entered
    else:
      break

#Print error message if invalids inputs are entered
  except ValueError:
    print("Error:The lower and higher number must be integers.")

#Call calculate_sum function and print the result
sum=calculate_sum(lower,higher)
print(f"The sum of integers between{lower} and {higher}is {sum}.")
# Out:
# Enter the lower number-5
# Enter the higher number11
# The sum of integers between-5 and 11is 51.

# %% [markdown]
# Question 3:

# %% [markdown]
# Create a Py Program that will create a graph of y = f(x) where;

# %% [markdown]
# f(x) = 3x2

# %% [markdown]
# And where

# %% [markdown]
# f(x) = 4x - 3

# %% [markdown]
# Your graph will need to plot the values of y for the values of x between -5 and +15 for both lines.
# To completely address this question you will need to;

# %% [markdown]
# ●	Correctly label the created graph with a title and labelled axes.

# %% [markdown]
# ●	Use a function to calculate the values of y for a given x value for both lines.

# %% [markdown]
# ●	Use plot markers for the graphs plotted points for both lines.

# %% [markdown]
# ●	Include a ‘grid’ on the graph.

# %% [markdown]
# ●	Present as evidence your code and the created graph with both lines visible.

# %%
#Akriti Kumari Dev
#University Id=2329584

#Import neccessary libraries
import matplotlib.pyplot as plt
import numpy as np

#Define two functions
def function_A(x):
  return 3*x**2

def function_B(x):
  return 4*x-3

#Generate a range of values for x
x=np.linspace(-5,15,50)

#Plot the two functions using the generated x values
plt.plot(x,function_A(x),marker='*',label='f(x)=3x^2')
plt.plot(x,function_B(x),marker='o',label='f(x)=4x-3')

#Set the title and labels for the plot, and turn on the grid
plt.title('Graph of y=f(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)

#Add a legend and display the plot
plt.legend()
plt.show()
